# %% [markdown]
# # EduTutor AI Development Notebook
#
# This notebook is for experimenting with AI models, data processing, and building components for the EduTutor AI web app.

# %%
# Import necessary libraries
from ai_module import EdututorAI
import pandas as pd
import numpy as np

# Initialize AI
edututor_ai = EdututorAI()

# Example student query
query = "Explain the concept of photosynthesis in simple terms."
response = edututor_ai.get_student_response(query)
print("AI Response:", response)

# Example assignment grading
assignment_text = "The process of photosynthesis involves plants converting sunlight into energy."
grade, feedback = edututor_ai.grade_assignment(assignment_text)
print(f"Grade: {grade}\nFeedback: {feedback}")
